# %%
# uncomment next line to install asteroidal package
#pip install asteroidal

# %% [markdown]
# Importing asteroid module from asteroidal

# %%
import asteroidal.asteroid as ast

# %% [markdown]
# To get started, create an Asteroid object using either the name of the asteroid, number (given by MPC), or Gaia source_id. Not all asteroids might have been observed by Gaia. Easiest way to get an asteroid is to try different asteroid numbers (Hint: No asteroid exists for number_mp < 8).
#
# Example: Create Asteroid object using name of asteroid (flora) and print table of all observations from Gaia

# %%
flora = ast.Asteroid(denomination='flora')
print(flora.observations)
# Out:
#  source_id    observation_id   ...         ra                 dec
#                                ...        deg                 deg
# ----------- ------------------ ... ------------------ -------------------
# -4284967216 180161746280534311 ... 125.08267668963693  18.484692390764558
# -4284967216 180161746280534312 ... 125.08270329285365  18.484688071339807
# -4284967216 180161746280534313 ... 125.08273504207796    18.4846824317617
# -4284967216 180161746280534314 ... 125.08276358823032   18.48467722038169
# -4284967216 180161746280534315 ... 125.08279236205239  18.484672630736558
# -4284967216 180161746280534316 ... 125.08282067632906  18.484667472811832
# -4284967216 180259137628616452 ... 125.17256221484175  18.469282083067817
# -4284967216 180259137628616453 ... 125.17259149571713   18.46927678767849
# -4284967216 180259137628616454 ... 125.17262006232227   18.46927214856378
# -4284967216 199584604068623602 ...  141.3358154971617   15.18396066453773
# ...

# %% [markdown]
# Plot all observations (ra, dec) as seen by Gaia

# %%
flora.plot_observations()

# %% [markdown]
# Plot the first transit observation

# %%
flora.plot_transit(0)

# %% [markdown]
# Plot all the transits seen by Gaia

# %%
flora.plot_all_transits()

# %% [markdown]
# Plot the orbit of Flora compared to the orbit of planets

# %%
flora.plot_orbits()

# %% [markdown]
# You can also plot the orbits of multiple asteroids by making array of Asteroid objects (takes a bit to query all asteroids).

# %%
asteroids = []
for num in range(8,30):
    asteroid = ast.Asteroid(number_mp=num)
    if asteroid.number_mp != 0:
        asteroids.append(asteroid)
        
ast.plot_multiple_orbits(asteroids)
# Out:
# Asteroid 9 does not exist in Gaia.
# Asteroid 10 does not exist in Gaia.
# Asteroid 11 does not exist in Gaia.
# Asteroid 12 does not exist in Gaia.
# Asteroid 13 does not exist in Gaia.
# Asteroid 15 does not exist in Gaia.
# Asteroid 16 does not exist in Gaia.
# Asteroid 18 does not exist in Gaia.
# Asteroid 20 does not exist in Gaia.
# Asteroid 22 does not exist in Gaia.
# Asteroid 23 does not exist in Gaia.
# Asteroid 25 does not exist in Gaia.
# Asteroid 27 does not exist in Gaia.
# Asteroid 28 does not exist in Gaia.
# Asteroid 29 does not exist in Gaia.
